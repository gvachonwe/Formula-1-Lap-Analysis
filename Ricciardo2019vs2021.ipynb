# %%
import fastf1 as ff1
from fastf1 import plotting
import matplotlib.pyplot as plt

# Plot setup

plotting.setup_mpl()
ff1.Cache.enable_cache('cache')

# Load sessions

session2019 = ff1.get_session(2019, 'Monaco GP', 'Q')
session2019.load()
session2021 = ff1.get_session(2021, 'Monaco GP', 'Q')
session2021.load()

lap2019 = session2019.laps.pick_driver('RIC').pick_fastest()
tel2019 = lap2019.get_car_data().add_distance()

lap2021 = session2021.laps.pick_driver('RIC').pick_fastest()
tel2021 = lap2021.get_car_data().add_distance()

# Initializing plot
fig, ax = plt.subplots(figsize=(15,8))

# Format plot

colourRenault = ff1.plotting.team_color('AST')
colourMcLaren = ff1.plotting.team_color('MCL')

ax.plot(tel2019['Distance'], tel2019['Speed'], color = colourRenault, label = '2019')
ax.plot(tel2021['Distance'], tel2021['Speed'], color = colourMcLaren, label = '2021')

ax.set_xlabel('Distance [m]')
ax.set_ylabel('Speed [km/h]')
ax.set_title('Ricciardo Qualifying Lap Comparison (Distance vs. Speed)')
ax.legend()
plt.show()
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v2.2.9]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '5', '10', '20', '3', '26', '55', '23', '27', '4', '8', '7', '99', '16', '11', '18', '63', '88']
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v2.2.9]
# api            INFO 	Using cached data for driver_info
# ...

# %%
# Plot setup

plotting.setup_mpl()
ff1.Cache.enable_cache('cache')

# Load sessions

session2019 = ff1.get_session(2019, 'Monaco GP', 'Q')
session2019.load()
session2021 = ff1.get_session(2021, 'Monaco GP', 'Q')
session2021.load()

lap2019 = session2019.laps.pick_driver('RIC').pick_fastest()
tel2019 = lap2019.get_car_data()

lap2021 = session2021.laps.pick_driver('RIC').pick_fastest()
tel2021 = lap2021.get_car_data()

# Initializing plot
fig, ax = plt.subplots(figsize=(15,8))

# Format plot

colourRenault = ff1.plotting.team_color('AST')
colourMcLaren = ff1.plotting.team_color('MCL')

ax.plot(tel2019['Time'], tel2019['Speed'], color = colourRenault, label = '2019')
ax.plot(tel2021['Time'], tel2021['Speed'], color = colourMcLaren, label = '2021')

ax.set_xlabel('Time [s]')
ax.set_ylabel('Speed [km/h]')
ax.set_title('Ricciardo Qualifying Lap Comparison (Time vs. Speed)')
ax.legend()
plt.show()
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v2.2.9]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['44', '77', '33', '5', '10', '20', '3', '26', '55', '23', '27', '4', '8', '7', '99', '16', '11', '18', '63', '88']
# core           INFO 	Loading data for Monaco Grand Prix - Qualifying [v2.2.9]
# api            INFO 	Using cached data for driver_info
# ...
